# %%
import numpy as np
import itertools
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, '../code/')
from tic_tac_toe import tic_tac_toe

# %matplotlib inline 
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Exercise 1.1 Self-Play
#
# Suppose, instead of playing against a random opponent, the reinforcement learning algorithm  described above played against itself, with both sides learning. What do you think would happen in this case? Would it learn a different policy for selecting moves?

# %% [markdown]
# ### Play 100 games of tic-tac-toe against itself

# %%
ttt = tic_tac_toe()
results = ttt.play(100)
print(results)

# for player X, plot distribution of values not equal to 0, 0.5 or 1
plt.figure(figsize=(16, 5))
_ = plt.hist(ttt.value_fun_x[~np.isin(ttt.value_fun_x, [0, 0.5, 1])], bins=100)
plt.title('Value Function of Player X')
plt.show()

# for player O, plot distribution of values not equal to 0, 0.5 or 1
plt.figure(figsize=(16, 5))
_ = plt.hist(ttt.value_fun_o[~np.isin(ttt.value_fun_o, [0, 0.5, 1])], bins=100)
plt.title('Value Function of Player O')
plt.show()
# Out:
# {'wins_x': 49, 'wins_o': 48, 'draws': 3}

# %%
ttt.num_movs
# Out:
# array([5., 6., 7., 6., 7., 5., 5., 6., 5., 5., 7., 5., 5., 6., 8., 5., 5.,
#        5., 5., 5., 9., 6., 5., 5., 6., 5., 9., 7., 6., 5., 8., 7., 5., 5.,
#        5., 5., 7., 6., 6., 5., 5., 5., 6., 7., 5., 6., 7., 7., 9., 7., 5.,
#        5., 9., 6., 6., 6., 5., 8., 5., 5., 5., 5., 5., 5., 6., 8., 5., 5.,
#        5., 7., 7., 9., 6., 5., 6., 6., 7., 5., 9., 8., 6., 5., 7., 5., 5.,
#        9., 6., 6., 5., 5., 5., 5., 5., 5., 7., 7., 6., 5., 5., 5.])

# %% [markdown]
# ### Play 1000 games of tic-tac-toe against itself

# %%
ttt = tic_tac_toe()
results = ttt.play(1000)
print(results)

# for player X, plot distribution of values not equal to 0, 0.5 or 1
plt.figure(figsize=(16, 5))
_ = plt.hist(ttt.value_fun_x[~np.isin(ttt.value_fun_x, [0, 0.5, 1])], bins=100)
plt.title('Value Function of Player X')
plt.show()

# for player O, plot distribution of values not equal to 0, 0.5 or 1
plt.figure(figsize=(16, 5))
_ = plt.hist(ttt.value_fun_o[~np.isin(ttt.value_fun_o, [0, 0.5, 1])], bins=100)
plt.title('Value Function of Player O')
plt.show()
# Out:
# {'wins_x': 450, 'wins_o': 513, 'draws': 37}

# %% [markdown]
# ### Play 10000 games of tic-tac-toe against itself

# %%
ttt = tic_tac_toe()
results = ttt.play(10000, eps=0.3)
print(results)

# for player X, plot distribution of values not equal to 0, 0.5 or 1
plt.figure(figsize=(16, 5))
_ = plt.hist(ttt.value_fun_x[~np.isin(ttt.value_fun_x, [0, 0.5, 1])], bins=100)
plt.title('Value Function of Player X')
plt.show()

# for player O, plot distribution of values not equal to 0, 0.5 or 1
plt.figure(figsize=(16, 5))
_ = plt.hist(ttt.value_fun_o[~np.isin(ttt.value_fun_o, [0, 0.5, 1])], bins=100)
plt.title('Value Function of Player O')
plt.show()
# Out:
# {'wins_x': 4843, 'wins_o': 4736, 'draws': 421}

# %%
plt.hist(ttt.num_movs,bins=[5,6,7,8,9,10])
# Out:
# (array([3613., 2626., 1801.,  882., 1078.]),
#  array([ 5,  6,  7,  8,  9, 10]),
#  <a list of 5 Patch objects>)

# %% [markdown]
# ### Play 100000 games of tic-tac-toe against itself

# %%
ttt.value_fun_0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-db279bda8e3c> in <module>()
# ----> 1 ttt.value_fun_0
#
# AttributeError: 'tic_tac_toe' object has no attribute 'value_fun_0'

# %%
ttt = tic_tac_toe()
results = ttt.play(100000, )
print(results)

# for player X, plot distribution of values not equal to 0, 0.5 or 1
plt.figure(figsize=(16, 5))
_ = plt.hist(ttt.value_fun_x[~np.isin(ttt.value_fun_x, [0, 0.5, 1])], bins=100)
plt.title('Value Function of Player X')
plt.show()

# for player O, plot distribution of values not equal to 0, 0.5 or 1
plt.figure(figsize=(16, 5))
_ = plt.hist(ttt.value_fun_o[~np.isin(ttt.value_fun_o, [0, 0.5, 1])], bins=100)
plt.title('Value Function of Player O')
plt.show()
# Out:
# {'wins_x': 49546, 'wins_o': 48789, 'draws': 1665}

# %%
plt.hist(ttt.num_movs,bins=[5,6,7,8,9,10])
# Out:
# (array([47013., 32987., 11858.,  4404.,  3738.]),
#  array([ 5,  6,  7,  8,  9, 10]),
#  <a list of 5 Patch objects>)

# %%
{'wins_x': 49755, 'draws': 1553, 'wins_o': 48692}

# %% [markdown]
# ### Play 1000000 games of tic-tac-toe against itself

# %%
ttt = tic_tac_toe()
results = ttt.play(1000000)
print(results)

# for player X, plot distribution of values not equal to 0, 0.5 or 1
plt.figure(figsize=(16, 5))
_ = plt.hist(ttt.value_fun_x[~np.isin(ttt.value_fun_x, [0, 0.5, 1])], bins=100)
plt.title('Value Function of Player X')
plt.show()

# for player O, plot distribution of values not equal to 0, 0.5 or 1
plt.figure(figsize=(16, 5))
_ = plt.hist(ttt.value_fun_o[~np.isin(ttt.value_fun_o, [0, 0.5, 1])], bins=100)
plt.title('Value Function of Player O')
plt.show()
# Out:
# {'wins_x': 483445, 'draws': 15632, 'wins_o': 500923}
